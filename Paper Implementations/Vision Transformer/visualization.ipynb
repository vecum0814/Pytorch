# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd/content/gdrive/My Drive/VisionTransformer
# Out:
# /content/gdrive/My Drive/VisionTransformer

# %%
import torch
from torch import nn
import model
import patchdata
import torchvision
import matplotlib.pyplot as plt
import torch.nn.functional as F
import numpy as np
import cv2

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
vit = model.VisionTransformer(patch_vec_size = 48, num_patches = 64,
                                  latent_vec_dim = 128, num_heads = 8, mlp_hidden_dim = 64,
                                  drop_rate=0., num_layers = 12, num_classes = 10).to(device)
vit.load_state_dict(torch.load('./model.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## 1. Linear Projection Weights

# %%
def minmax(x):
    m = torch.min(x)
    M = torch.max(x)
    return (M - x) / (M - m)

# %%
linear_embedding = vit.patchembedding.linear_proj.weight

# %%
# patch size = 4
# image channel = 3
# 1x(P^2C) -> linear_proj (CP^2)xD -> 1xD 저차원 매핑

# linear_embedding: (CP^2)xD
rgb_embedding_filters = linear_embedding.detach().cpu().view(3, 4, 4, -1).permute(3, 0, 1, 2) # (C x P x P x D) -> 최종적으로는 (D x C x P x P)

# %%
rgb_embedding_filters.size()
# Out:
# torch.Size([128, 3, 4, 4])

# %%
rgb_embedding_filters = minmax(rgb_embedding_filters)

# %%
# 64 rgb embedding filters out of 128
fig = plt.figure(figsize=(8, 8))
for i in range(1,65):
    rgb = rgb_embedding_filters[i - 1].numpy()
    ax = fig.add_subplot(8, 8, i)
    ax.axes.get_xaxis().set_visible(False) # x축 눈금 삭제
    ax.axes.get_yaxis().set_visible(False) # y축 눈금 삭제
    ax.imshow(rgb)

# %% [markdown]
# ## 2. Positional Embedding

# %%
pos_embedding = vit.patchembedding.pos_embedding # [1, 65, 128]

# %%
cos = torch.nn.CosineSimilarity(dim = 1, eps = 1e-6)
fig = plt.figure(figsize=(8, 8))
for i in range(1, pos_embedding.shape[1]):
    sim = F.cosine_similarity(pos_embedding[0, i : i + 1], pos_embedding[0, 1:], dim = 1)
    sim = sim.reshape((8, 8)).detach().cpu().numpy()
    ax = fig.add_subplot(8, 8, i)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.imshow(sim)

# %% [markdown]
# ## 3. Attention

# %%
def imshow(img):
    plt.figure(figsize = (4, 4))   
    plt.imshow(img.permute(1, 2, 0).numpy())
    plt.axis('off')
    plt.show()
    plt.close()
    return img

# %%
def inv_normal(img):
    img  = img.reshape(64, -1, 4, 4)
    mean = (0.4914, 0.4822, 0.4465)
    std = (0.2023, 0.1994, 0.2010)
    print(img.size())
    for i in range(3):
        img[:, i, :, :] = torch.abs(img[:, i, :, :] * std[i] + mean[i])
    return img

# %%
d = patchdata.Flattened2Dpatches(dataname = 'cifar10', img_size = 32, patch_size = 4,
                                     batch_size = 16)
_, _, testloader = d.patchdata()
image_patch, label = iter(testloader).next()
image_patch = image_patch[12:13]
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
sample = inv_normal(image_patch)
original_img = imshow(torchvision.utils.make_grid(sample, nrow = 8, padding = 0)) # padding != 0이면 흰색 격자가 있게 출력
# Out:
# torch.Size([64, 3, 4, 4])

# %%
print(original_img.size())
# Out:
# torch.Size([3, 32, 32])

# %%
_ = imshow(torchvision.utils.make_grid(sample, nrow = 8, padding = 1, pad_value = 1)) # pad_value = 1 -> white grid, 0 -> black grid

# %%
vit.eval()
output, attention = vit(image_patch.to(device))

# %%
attention = torch.stack(attention).squeeze(1) # [12, 1, 8, 65, 65] -> [12, 8, 65, 65], List 형태의 어텐션을 텐서로 바꿔준다. Layer 12, # Head 8

# %%
attention_heads = attention.view(-1, 65, 65)
attention_heads = minmax(attention_heads)

# %%
fig = plt.figure(figsize = (8, 12))
for i in range(1, 97):
    result = attention_heads[i - 1].detach().cpu().numpy()
    res_tensor = torch.Tensor(result)#.permute(1, 2, 0)
    ax = fig.add_subplot(12, 8, i)
    ax.axes.get_xaxis().set_visible(False) # x축 눈금 삭제
    ax.axes.get_yaxis().set_visible(False) # y축 눈금 삭제
    ax.imshow(res_tensor, vmin = np.min(result), vmax = np.max(result), cmap = 'jet')

# %% [markdown]
# ## Parameter name

# %%
for name, param in vit.named_parameters():
    print(name, param.size())
# Out:
# patchembedding.cls_token torch.Size([1, 128])
# patchembedding.pos_embedding torch.Size([1, 65, 128])
# patchembedding.linear_proj.weight torch.Size([128, 48])
# patchembedding.linear_proj.bias torch.Size([128])
# transformer.0.ln1.weight torch.Size([128])
# transformer.0.ln1.bias torch.Size([128])
# transformer.0.ln2.weight torch.Size([128])
# transformer.0.ln2.bias torch.Size([128])
# transformer.0.msa.query.weight torch.Size([128, 128])
# transformer.0.msa.query.bias torch.Size([128])
# transformer.0.msa.key.weight torch.Size([128, 128])
# transformer.0.msa.key.bias torch.Size([128])
# transformer.0.msa.value.weight torch.Size([128, 128])
# transformer.0.msa.value.bias torch.Size([128])
# transformer.0.mlp.0.weight torch.Size([64, 128])
# transformer.0.mlp.0.bias torch.Size([64])
# transformer.0.mlp.3.weight torch.Size([128, 64])
# transformer.0.mlp.3.bias torch.Size([128])
# transformer.1.ln1.weight torch.Size([128])
# transformer.1.ln1.bias torch.Size([128])
# transformer.1.ln2.weight torch.Size([128])
# transformer.1.ln2.bias torch.Size([128])
# transformer.1.msa.query.weight torch.Size([128, 128])
# transformer.1.msa.query.bias torch.Size([128])
# transformer.1.msa.key.weight torch.Size([128, 128])
# transformer.1.msa.key.bias torch.Size([128])
# transformer.1.msa.value.weight torch.Size([128, 128])
# transformer.1.msa.value.bias torch.Size([128])
# transformer.1.mlp.0.weight torch.Size([64, 128])
# transformer.1.mlp.0.bias torch.Size([64])
# transformer.1.mlp.3.weight torch.Size([128, 64])
# transformer.1.mlp.3.bias torch.Size([128])
# transformer.2.ln1.weight torch.Size([128])
# transformer.2.ln1.bias torch.Size([128])
# transformer.2.ln2.weight torch.Size([128])
# transformer.2.ln2.bias torch.Size([128])
# transformer.2.msa.query.weight torch.Size([128, 128])
# transformer.2.msa.query.bias torch.Size([128])
# transformer.2.msa.key.weight torch.Size([128, 128])
# transformer.2.msa.key.bias torch.Size([128])
# transformer.2.msa.value.weight torch.Size([128, 128])
# transformer.2.msa.value.bias torch.Size([128])
# transformer.2.mlp.0.weight torch.Size([64, 128])
# transformer.2.mlp.0.bias torch.Size([64])
# transformer.2.mlp.3.weight torch.Size([128, 64])
# transformer.2.mlp.3.bias torch.Size([128])
# transformer.3.ln1.weight torch.Size([128])
# transformer.3.ln1.bias torch.Size([128])
# transformer.3.ln2.weight torch.Size([128])
# transformer.3.ln2.bias torch.Size([128])
# transformer.3.msa.query.weight torch.Size([128, 128])
# transformer.3.msa.query.bias torch.Size([128])
# transformer.3.msa.key.weight torch.Size([128, 128])
# transformer.3.msa.key.bias torch.Size([128])
# transformer.3.msa.value.weight torch.Size([128, 128])
# transformer.3.msa.value.bias torch.Size([128])
# transformer.3.mlp.0.weight torch.Size([64, 128])
# transformer.3.mlp.0.bias torch.Size([64])
# transformer.3.mlp.3.weight torch.Size([128, 64])
# transformer.3.mlp.3.bias torch.Size([128])
# transformer.4.ln1.weight torch.Size([128])
# transformer.4.ln1.bias torch.Size([128])
# transformer.4.ln2.weight torch.Size([128])
# transformer.4.ln2.bias torch.Size([128])
# transformer.4.msa.query.weight torch.Size([128, 128])
# transformer.4.msa.query.bias torch.Size([128])
# transformer.4.msa.key.weight torch.Size([128, 128])
# transformer.4.msa.key.bias torch.Size([128])
# transformer.4.msa.value.weight torch.Size([128, 128])
# transformer.4.msa.value.bias torch.Size([128])
# transformer.4.mlp.0.weight torch.Size([64, 128])
# transformer.4.mlp.0.bias torch.Size([64])
# transformer.4.mlp.3.weight torch.Size([128, 64])
# transformer.4.mlp.3.bias torch.Size([128])
# transformer.5.ln1.weight torch.Size([128])
# transformer.5.ln1.bias torch.Size([128])
# transformer.5.ln2.weight torch.Size([128])
# transformer.5.ln2.bias torch.Size([128])
# transformer.5.msa.query.weight torch.Size([128, 128])
# transformer.5.msa.query.bias torch.Size([128])
# transformer.5.msa.key.weight torch.Size([128, 128])
# transformer.5.msa.key.bias torch.Size([128])
# transformer.5.msa.value.weight torch.Size([128, 128])
# transformer.5.msa.value.bias torch.Size([128])
# transformer.5.mlp.0.weight torch.Size([64, 128])
# transformer.5.mlp.0.bias torch.Size([64])
# transformer.5.mlp.3.weight torch.Size([128, 64])
# transformer.5.mlp.3.bias torch.Size([128])
# transformer.6.ln1.weight torch.Size([128])
# transformer.6.ln1.bias torch.Size([128])
# transformer.6.ln2.weight torch.Size([128])
# transformer.6.ln2.bias torch.Size([128])
# transformer.6.msa.query.weight torch.Size([128, 128])
# transformer.6.msa.query.bias torch.Size([128])
# transformer.6.msa.key.weight torch.Size([128, 128])
# transformer.6.msa.key.bias torch.Size([128])
# transformer.6.msa.value.weight torch.Size([128, 128])
# transformer.6.msa.value.bias torch.Size([128])
# transformer.6.mlp.0.weight torch.Size([64, 128])
# transformer.6.mlp.0.bias torch.Size([64])
# transformer.6.mlp.3.weight torch.Size([128, 64])
# transformer.6.mlp.3.bias torch.Size([128])
# transformer.7.ln1.weight torch.Size([128])
# transformer.7.ln1.bias torch.Size([128])
# transformer.7.ln2.weight torch.Size([128])
# transformer.7.ln2.bias torch.Size([128])
# transformer.7.msa.query.weight torch.Size([128, 128])
# transformer.7.msa.query.bias torch.Size([128])
# transformer.7.msa.key.weight torch.Size([128, 128])
# transformer.7.msa.key.bias torch.Size([128])
# transformer.7.msa.value.weight torch.Size([128, 128])
# transformer.7.msa.value.bias torch.Size([128])
# transformer.7.mlp.0.weight torch.Size([64, 128])
# transformer.7.mlp.0.bias torch.Size([64])
# transformer.7.mlp.3.weight torch.Size([128, 64])
# transformer.7.mlp.3.bias torch.Size([128])
# transformer.8.ln1.weight torch.Size([128])
# transformer.8.ln1.bias torch.Size([128])
# transformer.8.ln2.weight torch.Size([128])
# transformer.8.ln2.bias torch.Size([128])
# transformer.8.msa.query.weight torch.Size([128, 128])
# transformer.8.msa.query.bias torch.Size([128])
# transformer.8.msa.key.weight torch.Size([128, 128])
# transformer.8.msa.key.bias torch.Size([128])
# transformer.8.msa.value.weight torch.Size([128, 128])
# transformer.8.msa.value.bias torch.Size([128])
# transformer.8.mlp.0.weight torch.Size([64, 128])
# transformer.8.mlp.0.bias torch.Size([64])
# transformer.8.mlp.3.weight torch.Size([128, 64])
# transformer.8.mlp.3.bias torch.Size([128])
# transformer.9.ln1.weight torch.Size([128])
# transformer.9.ln1.bias torch.Size([128])
# transformer.9.ln2.weight torch.Size([128])
# transformer.9.ln2.bias torch.Size([128])
# transformer.9.msa.query.weight torch.Size([128, 128])
# transformer.9.msa.query.bias torch.Size([128])
# transformer.9.msa.key.weight torch.Size([128, 128])
# transformer.9.msa.key.bias torch.Size([128])
# transformer.9.msa.value.weight torch.Size([128, 128])
# transformer.9.msa.value.bias torch.Size([128])
# transformer.9.mlp.0.weight torch.Size([64, 128])
# transformer.9.mlp.0.bias torch.Size([64])
# transformer.9.mlp.3.weight torch.Size([128, 64])
# transformer.9.mlp.3.bias torch.Size([128])
# transformer.10.ln1.weight torch.Size([128])
# transformer.10.ln1.bias torch.Size([128])
# transformer.10.ln2.weight torch.Size([128])
# transformer.10.ln2.bias torch.Size([128])
# transformer.10.msa.query.weight torch.Size([128, 128])
# transformer.10.msa.query.bias torch.Size([128])
# transformer.10.msa.key.weight torch.Size([128, 128])
# transformer.10.msa.key.bias torch.Size([128])
# transformer.10.msa.value.weight torch.Size([128, 128])
# transformer.10.msa.value.bias torch.Size([128])
# transformer.10.mlp.0.weight torch.Size([64, 128])
# transformer.10.mlp.0.bias torch.Size([64])
# transformer.10.mlp.3.weight torch.Size([128, 64])
# transformer.10.mlp.3.bias torch.Size([128])
# transformer.11.ln1.weight torch.Size([128])
# transformer.11.ln1.bias torch.Size([128])
# transformer.11.ln2.weight torch.Size([128])
# transformer.11.ln2.bias torch.Size([128])
# transformer.11.msa.query.weight torch.Size([128, 128])
# transformer.11.msa.query.bias torch.Size([128])
# transformer.11.msa.key.weight torch.Size([128, 128])
# transformer.11.msa.key.bias torch.Size([128])
# transformer.11.msa.value.weight torch.Size([128, 128])
# transformer.11.msa.value.bias torch.Size([128])
# transformer.11.mlp.0.weight torch.Size([64, 128])
# transformer.11.mlp.0.bias torch.Size([64])
# transformer.11.mlp.3.weight torch.Size([128, 64])
# transformer.11.mlp.3.bias torch.Size([128])
# mlp_head.0.weight torch.Size([128])
# mlp_head.0.bias torch.Size([128])
# mlp_head.1.weight torch.Size([10, 128])
# mlp_head.1.bias torch.Size([10])
